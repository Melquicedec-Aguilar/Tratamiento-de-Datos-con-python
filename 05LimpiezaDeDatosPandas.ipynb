# %% [markdown]
# <a href="https://colab.research.google.com/github/Melquicedec-Aguilar/Tratamiento-de-datos-con-python/blob/main/05LimpiezaDeDatosPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Limpieza de datos con Pandas

# %%
import pandas as pd
import numpy as np
import datetime as dt
import re

# %%
#Leer origen de datos
df = pd.read_csv('https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/aerolineas.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nrow           2480 non-null   int64
#  1   id             2480 non-null   int64
#  2   dia            2480 non-null   object
#  3   aerolinea      2480 non-null   object
#  4   destino        2480 non-null   object
#  5   region         2480 non-null   object
#  6   dest_size      2480 non-null   object
#  7   area_abordaje  2480 non-null   object
#  8   fecha_salida   2480 non-null   object
#  9   espera_min     2474 non-null   float64
#  10  limpieza       2480 non-null   object
#  11  seguridad      2480 non-null   object
#  12  satisfaccion   2480 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 252.0+ KB

# %%
df.head()
# Out:
#    nrow    id        dia    aerolinea            destino            region  \
# 0     0  1351     martes  UNITED INTL             KANSAI              Asia
# 1     1   373    viernes       ALASKA  SAN JOSE DEL CABO   Canada / Mexico
# 2     2  2820     jueves        DELTA        LOS ÁNGELES  oeste de EE. UU.
# 3     3  1157     martes     SUDOESTE        LOS ÁNGELES  oeste de EE. UU.
# 4     4  2992  miércoles     AMERICAN              MIAMI           East US
#
#   dest_size area_abordaje fecha_salida  espera_min     limpieza    seguridad  \
# 0       Hub  Gates 91-102   2018-12-31       115.0       Limpio      Neutral
# 1     Small   Gates 50-59   2018-12-31       135.0       Limpio   Muy seguro
# 2      Hub    Gates 40-48   2018-12-31        70.0     Promedio  Algo seguro
# 3      Hub    Gates 20-39   2018-12-31       190.0       Limpio   Muy seguro
# 4       Hub   Gates 50-59   2018-12-31       559.0  Inaceptable   Muy seguro
#
#       satisfaccion
# 0   Muy satisfecho
# 1   Muy satisfecho
# 2          Neutral
# 3  Algo satisfecho
# 4  Algo satisfecho

# %%
df.tail()
# Out:
#       nrow    id      dia      aerolinea         destino            region  \
# 2475  2804  1475   martes         ALASKA  NUEVA YORK-JFK   este de EE. UU.
# 2476  2805  2222   jueves       SUDOESTE         PHOENIX  oeste de EE. UU.
# 2477  2806  2684  viernes         UNITED         ORLANDO   Este de EE. UU.
# 2478  2807  2549   martes        JETBLUE      LONG BEACH  oeste de EE. UU.
# 2479  2808  2162   sábado  ESTE DE CHINA         QINGDAO              Asia
#
#      dest_size area_abordaje fecha_salida  espera_min     limpieza  \
# 2475       Hub   Gates 50-59   2018-12-31       280.0  Algo limpio
# 2476      Hub    Gates 20-39   2018-12-31       165.0       Limpio
# 2477       Hub   Gates 70-90   2018-12-31        92.0       Limpio
# 2478     Small    Gates 1-12   2018-12-31        95.0       Limpio
# 2479    grande    Gates 1-12   2018-12-31       220.0       Limpio
#
#         seguridad     satisfaccion
# 2475      Neutral  Algo satisfecho
# 2476   Muy seguro   Muy satisfecho
# 2477   Muy seguro   Muy satisfecho
# 2478  Algo seguro   Muy satisfecho
# 2479   Muy seguro  Algo satisfecho

# %%
#Visualizar el numero de datos faltantes
df.isnull().sum()
# Out:
# nrow             0
# id               0
# dia              0
# aerolinea        0
# destino          0
# region           0
# dest_size        0
# area_abordaje    0
# fecha_salida     0
# espera_min       6
# limpieza         0
# seguridad        0
# satisfaccion     0
# dtype: int64

# %%
df[pd.isnull(df['espera_min'])]
# Out:
#       nrow    id        dia aerolinea           destino  \
# 183    206  1843  miércoles  SUDOESTE         SAN DIEGO
# 240    273   325     jueves    UNITED           BURBANK
# 256    293  1180     martes  SUDOESTE         LAS VEGAS
# 673    765  1215     martes  SUDOESTE         LAS VEGAS
# 1036  1176   847     martes  AMERICAN  DALLAS-FT. VALOR
# 2227  2538  1224     martes  SUDOESTE         LAS VEGAS
#
#                       region dest_size area_abordaje fecha_salida  espera_min  \
# 183         oeste de EE. UU.    Medium   Gates 20-39   2018-12-31         NaN
# 240                  West US     Small   Gates 70-90   2018-12-31         NaN
# 256         oeste de EE. UU.      Hub    Gates 20-39   2018-12-31         NaN
# 673         oeste de EE. UU.      Hub    Gates 20-39   2018-12-31         NaN
# 1036  Medio Oeste de EE. UU.       Hub   Gates 50-59   2018-12-31         NaN
# 2227        oeste de EE. UU.      Hub    Gates 20-39   2018-12-31         NaN
#
#          limpieza    seguridad     satisfaccion
# 183         Medio  Algo seguro  Algo satisfecho
# 240   Algo limpio   Muy seguro  Algo satisfecho
# 256        Limpio   Muy seguro  Algo satisfecho
# 673        Limpio  Algo seguro  Algo satisfecho
# 1036       Limpio  Algo seguro  Algo satisfecho
# 2227     Promedio  Algo seguro          Neutral

# %%
df[pd.isnull(df['espera_min'])]['espera_min']
# Out:
# 183    NaN
# 240    NaN
# 256    NaN
# 673    NaN
# 1036   NaN
# 2227   NaN
# Name: espera_min, dtype: float64

# %%
df_nan = df[pd.isnull(df['espera_min'])]['espera_min'].isna()
df_nan
# Out:
# 183     True
# 240     True
# 256     True
# 673     True
# 1036    True
# 2227    True
# Name: espera_min, dtype: bool

# %%
#Ver los descriptivos de espera en minutos
df['espera_min'].describe()
# Out:
# count    2474.000000
# mean      166.372676
# std       107.582681
# min        15.000000
# 25%       105.000000
# 50%       145.000000
# 75%       189.250000
# max      1365.000000
# Name: espera_min, dtype: float64

# %%
df.iloc[2227]
# Out:
# nrow                         2538
# id                           1224
# dia                        martes
# aerolinea                SUDOESTE
# destino                 LAS VEGAS
# region           oeste de EE. UU.
# dest_size                    Hub
# area_abordaje         Gates 20-39
# fecha_salida           2018-12-31
# espera_min                    NaN
# limpieza                 Promedio
# seguridad             Algo seguro
# satisfaccion              Neutral
# Name: 2227, dtype: object

# %%
#Cambiar los valores NaN por el promedio de espera_min
df['espera_min'].fillna((df['espera_min'].mean()), inplace=True)

# %%
df.isnull().sum()
# Out:
# nrow             0
# id               0
# dia              0
# aerolinea        0
# destino          0
# region           0
# dest_size        0
# area_abordaje    0
# fecha_salida     0
# espera_min       0
# limpieza         0
# seguridad        0
# satisfaccion     0
# dtype: int64

# %%
#Visualizar los cambios de valores NaN
print(df_nan.index)
df[df.index.isin(df_nan.index)]
# Out:
# Int64Index([183, 240, 256, 673, 1036, 2227], dtype='int64')
#       nrow    id        dia aerolinea           destino  \
# 183    206  1843  miércoles  SUDOESTE         SAN DIEGO
# 240    273   325     jueves    UNITED           BURBANK
# 256    293  1180     martes  SUDOESTE         LAS VEGAS
# 673    765  1215     martes  SUDOESTE         LAS VEGAS
# 1036  1176   847     martes  AMERICAN  DALLAS-FT. VALOR
# 2227  2538  1224     martes  SUDOESTE         LAS VEGAS
#
#                       region dest_size area_abordaje fecha_salida  espera_min  \
# 183         oeste de EE. UU.    Medium   Gates 20-39   2018-12-31  166.372676
# 240                  West US     Small   Gates 70-90   2018-12-31  166.372676
# 256         oeste de EE. UU.      Hub    Gates 20-39   2018-12-31  166.372676
# 673         oeste de EE. UU.      Hub    Gates 20-39   2018-12-31  166.372676
# 1036  Medio Oeste de EE. UU.       Hub   Gates 50-59   2018-12-31  166.372676
# 2227        oeste de EE. UU.      Hub    Gates 20-39   2018-12-31  166.372676
#
#          limpieza    seguridad     satisfaccion
# 183         Medio  Algo seguro  Algo satisfecho
# 240   Algo limpio   Muy seguro  Algo satisfecho
# 256        Limpio   Muy seguro  Algo satisfecho
# 673        Limpio  Algo seguro  Algo satisfecho
# 1036       Limpio  Algo seguro  Algo satisfecho
# 2227     Promedio  Algo seguro          Neutral

# %%
#Eliminar columnas
df.drop(['nrow'], axis=1)
# Out:
#         id        dia      aerolinea            destino            region  \
# 0     1351     martes    UNITED INTL             KANSAI              Asia
# 1      373    viernes         ALASKA  SAN JOSE DEL CABO   Canada / Mexico
# 2     2820     jueves          DELTA        LOS ÁNGELES  oeste de EE. UU.
# 3     1157     martes       SUDOESTE        LOS ÁNGELES  oeste de EE. UU.
# 4     2992  miércoles       AMERICAN              MIAMI           East US
# ...    ...        ...            ...                ...               ...
# 2475  1475     martes         ALASKA     NUEVA YORK-JFK   este de EE. UU.
# 2476  2222     jueves       SUDOESTE            PHOENIX  oeste de EE. UU.
# 2477  2684    viernes         UNITED            ORLANDO   Este de EE. UU.
# 2478  2549     martes        JETBLUE         LONG BEACH  oeste de EE. UU.
# 2479  2162     sábado  ESTE DE CHINA            QINGDAO              Asia
#
#      dest_size area_abordaje fecha_salida  espera_min     limpieza  \
# 0          Hub  Gates 91-102   2018-12-31       115.0       Limpio
# 1        Small   Gates 50-59   2018-12-31       135.0       Limpio
# 2         Hub    Gates 40-48   2018-12-31        70.0     Promedio
# 3         Hub    Gates 20-39   2018-12-31       190.0       Limpio
# 4          Hub   Gates 50-59   2018-12-31       559.0  Inaceptable
# ...        ...           ...          ...         ...          ...
# 2475       Hub   Gates 50-59   2018-12-31       280.0  Algo limpio
# 2476      Hub    Gates 20-39   2018-12-31       165.0       Limpio
# 2477       Hub   Gates 70-90   2018-12-31        92.0       Limpio
# 2478     Small    Gates 1-12   2018-12-31        95.0       Limpio
# 2479    grande    Gates 1-12   2018-12-31       220.0       Limpio
#
#         seguridad     satisfaccion
# 0         Neutral   Muy satisfecho
# 1      Muy seguro   Muy satisfecho
# 2     Algo seguro          Neutral
# 3      Muy seguro  Algo satisfecho
# 4      Muy seguro  Algo satisfecho
# ...           ...              ...
# 2475      Neutral  Algo satisfecho
# 2476   Muy seguro   Muy satisfecho
# 2477   Muy seguro   Muy satisfecho
# 2478  Algo seguro   Muy satisfecho
# 2479   Muy seguro  Algo satisfecho
#
# [2480 rows x 12 columns]

# %%
#Crear columnas
df['espera_hr'] = df['espera_min'] / 60
df[['id', 'aerolinea', 'espera_min', 'espera_hr']]
# Out:
#         id      aerolinea  espera_min  espera_hr
# 0     1351    UNITED INTL       115.0   1.916667
# 1      373         ALASKA       135.0   2.250000
# 2     2820          DELTA        70.0   1.166667
# 3     1157       SUDOESTE       190.0   3.166667
# 4     2992       AMERICAN       559.0   9.316667
# ...    ...            ...         ...        ...
# 2475  1475         ALASKA       280.0   4.666667
# 2476  2222       SUDOESTE       165.0   2.750000
# 2477  2684         UNITED        92.0   1.533333
# 2478  2549        JETBLUE        95.0   1.583333
# 2479  2162  ESTE DE CHINA       220.0   3.666667
#
# [2480 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nrow           2480 non-null   int64
#  1   id             2480 non-null   int64
#  2   dia            2480 non-null   object
#  3   aerolinea      2480 non-null   object
#  4   destino        2480 non-null   object
#  5   region         2480 non-null   object
#  6   dest_size      2480 non-null   object
#  7   area_abordaje  2480 non-null   object
#  8   fecha_salida   2480 non-null   object
#  9   espera_min     2480 non-null   float64
#  10  limpieza       2480 non-null   object
#  11  seguridad      2480 non-null   object
#  12  satisfaccion   2480 non-null   object
#  13  espera_hr      2480 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 271.4+ KB

# %%
#Convertir columnas tipo cadenas(object) a tipo date
df['fecha_salida'] = pd.to_datetime(df['fecha_salida']).dt.date
df
# Out:
#       nrow    id        dia      aerolinea            destino  \
# 0        0  1351     martes    UNITED INTL             KANSAI
# 1        1   373    viernes         ALASKA  SAN JOSE DEL CABO
# 2        2  2820     jueves          DELTA        LOS ÁNGELES
# 3        3  1157     martes       SUDOESTE        LOS ÁNGELES
# 4        4  2992  miércoles       AMERICAN              MIAMI
# ...    ...   ...        ...            ...                ...
# 2475  2804  1475     martes         ALASKA     NUEVA YORK-JFK
# 2476  2805  2222     jueves       SUDOESTE            PHOENIX
# 2477  2806  2684    viernes         UNITED            ORLANDO
# 2478  2807  2549     martes        JETBLUE         LONG BEACH
# 2479  2808  2162     sábado  ESTE DE CHINA            QINGDAO
#
#                 region dest_size area_abordaje fecha_salida  espera_min  \
# 0                 Asia       Hub  Gates 91-102   2018-12-31       115.0
# 1      Canada / Mexico     Small   Gates 50-59   2018-12-31       135.0
# 2     oeste de EE. UU.      Hub    Gates 40-48   2018-12-31        70.0
# 3     oeste de EE. UU.      Hub    Gates 20-39   2018-12-31       190.0
# 4              East US       Hub   Gates 50-59   2018-12-31       559.0
# ...                ...       ...           ...          ...         ...
# 2475   este de EE. UU.       Hub   Gates 50-59   2018-12-31       280.0
# 2476  oeste de EE. UU.      Hub    Gates 20-39   2018-12-31       165.0
# 2477   Este de EE. UU.       Hub   Gates 70-90   2018-12-31        92.0
# 2478  oeste de EE. UU.     Small    Gates 1-12   2018-12-31        95.0
# 2479              Asia    grande    Gates 1-12   2018-12-31       220.0
#
#          limpieza    seguridad     satisfaccion  espera_hr
# 0          Limpio      Neutral   Muy satisfecho   1.916667
# 1          Limpio   Muy seguro   Muy satisfecho   2.250000
# 2        Promedio  Algo seguro          Neutral   1.166667
# 3          Limpio   Muy seguro  Algo satisfecho   3.166667
# 4     Inaceptable   Muy seguro  Algo satisfecho   9.316667
# ...           ...          ...              ...        ...
# 2475  Algo limpio      Neutral  Algo satisfecho   4.666667
# 2476       Limpio   Muy seguro   Muy satisfecho   2.750000
# 2477       Limpio   Muy seguro   Muy satisfecho   1.533333
# 2478       Limpio  Algo seguro   Muy satisfecho   1.583333
# 2479       Limpio   Muy seguro  Algo satisfecho   3.666667
#
# [2480 rows x 14 columns]

# %%
print(df['fecha_salida'].describe())
print("Fecha minima ", df['fecha_salida'].min())
print("Fecha maxima ", df['fecha_salida'].max())
# Out:
# count           2480
# unique             2
# top       2018-12-31
# freq            2443
# Name: fecha_salida, dtype: object
# Fecha minima  2018-01-01
# Fecha maxima  2018-12-31

# %%
#Filtar renglones por fecha
df.loc[df['fecha_salida'] == dt.date(year=2018, month=12, day=31)]
# Out:
#       nrow    id        dia      aerolinea            destino  \
# 0        0  1351     martes    UNITED INTL             KANSAI
# 1        1   373    viernes         ALASKA  SAN JOSE DEL CABO
# 2        2  2820     jueves          DELTA        LOS ÁNGELES
# 3        3  1157     martes       SUDOESTE        LOS ÁNGELES
# 4        4  2992  miércoles       AMERICAN              MIAMI
# ...    ...   ...        ...            ...                ...
# 2475  2804  1475     martes         ALASKA     NUEVA YORK-JFK
# 2476  2805  2222     jueves       SUDOESTE            PHOENIX
# 2477  2806  2684    viernes         UNITED            ORLANDO
# 2478  2807  2549     martes        JETBLUE         LONG BEACH
# 2479  2808  2162     sábado  ESTE DE CHINA            QINGDAO
#
#                 region dest_size area_abordaje fecha_salida  espera_min  \
# 0                 Asia       Hub  Gates 91-102   2018-12-31       115.0
# 1      Canada / Mexico     Small   Gates 50-59   2018-12-31       135.0
# 2     oeste de EE. UU.      Hub    Gates 40-48   2018-12-31        70.0
# 3     oeste de EE. UU.      Hub    Gates 20-39   2018-12-31       190.0
# 4              East US       Hub   Gates 50-59   2018-12-31       559.0
# ...                ...       ...           ...          ...         ...
# 2475   este de EE. UU.       Hub   Gates 50-59   2018-12-31       280.0
# 2476  oeste de EE. UU.      Hub    Gates 20-39   2018-12-31       165.0
# 2477   Este de EE. UU.       Hub   Gates 70-90   2018-12-31        92.0
# 2478  oeste de EE. UU.     Small    Gates 1-12   2018-12-31        95.0
# 2479              Asia    grande    Gates 1-12   2018-12-31       220.0
#
#          limpieza    seguridad     satisfaccion  espera_hr
# 0          Limpio      Neutral   Muy satisfecho   1.916667
# 1          Limpio   Muy seguro   Muy satisfecho   2.250000
# 2        Promedio  Algo seguro          Neutral   1.166667
# 3          Limpio   Muy seguro  Algo satisfecho   3.166667
# 4     Inaceptable   Muy seguro  Algo satisfecho   9.316667
# ...           ...          ...              ...        ...
# 2475  Algo limpio      Neutral  Algo satisfecho   4.666667
# 2476       Limpio   Muy seguro   Muy satisfecho   2.750000
# 2477       Limpio   Muy seguro   Muy satisfecho   1.533333
# 2478       Limpio  Algo seguro   Muy satisfecho   1.583333
# 2479       Limpio   Muy seguro  Algo satisfecho   3.666667
#
# [2443 rows x 14 columns]

# %%
#Localizar renglones duplicados
df_dup = df.duplicated()
df_dup
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2475    False
# 2476    False
# 2477    False
# 2478    False
# 2479    False
# Length: 2480, dtype: bool

# %%
#Localizamos los renglones duplicados
df[df_dup]
# Out:
#      nrow    id        dia     aerolinea            destino            region  \
# 523   574  1510  miércoles  HAWAIIAN AIR           HONOLULU  oeste de EE. UU.
# 576   642   370    viernes        ALASKA  SAN JOSE DEL CABO   Canadá / México
#
#     dest_size area_abordaje fecha_salida  espera_min     limpieza  \
# 523    Medium    Gates 1-12   2018-12-31       120.0  Algo limpio
# 576     Small   Gates 50-59   2018-12-31       195.0  Algo limpio
#
#        seguridad     satisfaccion  espera_hr
# 523   Muy seguro          Neutral       2.00
# 576  Algo seguro  Algo satisfecho       3.25

# %%
#Definir columnas a evaluar duplicado
col = ['id', 'dia', 'aerolinea']
df_dup = df.duplicated(subset=col, keep = False)
df[df_dup].sort_values(by= 'id')
# Out:
#      nrow    id        dia     aerolinea            destino            region  \
# 559   642   370    viernes        ALASKA  SAN JOSE DEL CABO   Canadá / México
# 576   642   370    viernes        ALASKA  SAN JOSE DEL CABO   Canadá / México
# 501   574  1510  miércoles  HAWAIIAN AIR           HONOLULU  oeste de EE. UU.
# 523   574  1510  miércoles  HAWAIIAN AIR           HONOLULU  oeste de EE. UU.
#
#     dest_size area_abordaje fecha_salida  espera_min     limpieza  \
# 559     Small   Gates 50-59   2018-12-31       195.0  Algo limpio
# 576     Small   Gates 50-59   2018-12-31       195.0  Algo limpio
# 501    Medium    Gates 1-12   2018-12-31       120.0  Algo limpio
# 523    Medium    Gates 1-12   2018-12-31       120.0  Algo limpio
#
#        seguridad     satisfaccion  espera_hr
# 559  Algo seguro  Algo satisfecho       3.25
# 576  Algo seguro  Algo satisfecho       3.25
# 501   Muy seguro          Neutral       2.00
# 523   Muy seguro          Neutral       2.00

# %%
#Eliminar duplicados
df.drop_duplicates(inplace = True)
df.count()

#Elimina un renglon
#df.drop([523], axis=0)
# Out:
# nrow             2478
# id               2478
# dia              2478
# aerolinea        2478
# destino          2478
# region           2478
# dest_size        2478
# area_abordaje    2478
# fecha_salida     2478
# espera_min       2478
# limpieza         2478
# seguridad        2478
# satisfaccion     2478
# espera_hr        2478
# dtype: int64

# %%
#Cargar el DF de categorias
df_cat = pd.read_csv('https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/categorias.csv')
df_cat
# Out:
#       limpieza       seguridad        satisfaccion
# 0       Limpio         Neutral   Muy satisfactorio
# 1     Promedio      Muy seguro             Neutral
# 2  Algo limpio     Algo seguro     Algo satisfecho
# 3   Algo sucio    Muy inseguro   Algo insatisfecho
# 4        Sucio   Algo inseguro    Muy insatisfecho

# %%
#Visualizar los valores unicos de cada columna categorica (limpieza, seguridad, satisfaccion )
# unique()
print('Limpieza', df['limpieza'].unique())
print('Seguridas', df['seguridad'].unique())
print('Satisfaccion', df['satisfaccion'].unique())
# Out:
# Limpieza ['Limpio' 'Promedio' 'Inaceptable' 'Algo limpio' 'Algo sucio' 'Medio'
#  'Sucio']
# Seguridas ['Neutral' 'Muy seguro' 'Algo seguro' 'Muy inseguro' 'Algo inseguro']
# Satisfaccion ['Muy satisfecho' 'Neutral' 'Algo satisfecho' 'Algo insatisfecho'
#  'Muy insatisfecho']

# %%
# Localizar los valores invalidos en la columna limpieza
df_limpieza = set(df['limpieza']).difference(df_cat['limpieza'])
df_limpieza
# Out:
# {'Inaceptable', 'Medio'}

# %%
#Localizar renglones que no tienen un valor valido para limpieza
df_lim_r = df['limpieza'].isin(df_limpieza)
df[df_lim_r]
# Out:
#       nrow    id        dia            aerolinea         destino  \
# 4        4  2992  miércoles             AMERICAN           MIAMI
# 60      67  3151     jueves                DELTA  SALT LAKE CITY
# 183    206  1843  miércoles             SUDOESTE       SAN DIEGO
# 493    566   447    domingo               UNITED    INDIANAPOLIS
# 582    665  3055    domingo  PHILIPPINE AIRLINES          MANILA
# 1309  1494  1035    viernes           AIR CANADA       VANCOUVER
# 1563  1777  3032     martes               UNITED        PORTLAND
# 1932  2200   938     jueves           AIR CANADA       VANCOUVER
# 2047  2338  2135  miércoles           AIR CANADA       VANCOUVER
# 2381  2703  1147     martes             SUDOESTE       SAN DIEGO
#
#                       region dest_size area_abordaje fecha_salida  espera_min  \
# 4                    East US       Hub   Gates 50-59   2018-12-31  559.000000
# 60          oeste de EE. UU.    Medium   Gates 40-48   2018-12-31   15.000000
# 183         oeste de EE. UU.    Medium   Gates 20-39   2018-12-31  166.372676
# 493   Medio Oeste de EE. UU.    Medium   Gates 60-69   2018-12-31   83.000000
# 582                     Asia    Medium    Gates 1-12   2018-01-01  335.000000
# 1309         Canadá / México    Medium  Gates 91-102   2018-12-31   95.000000
# 1563        oeste de EE. UU.    Medium   Gates 70-90   2018-12-31   95.000000
# 1932         Canadá / México    Medium  Gates 91-102   2018-12-31  105.000000
# 2047         Canadá / México    Medium  Gates 91-102   2018-12-31   95.000000
# 2381        oeste de EE. UU.    Medium   Gates 20-39   2018-12-31   60.000000
#
#          limpieza    seguridad     satisfaccion  espera_hr
# 4     Inaceptable   Muy seguro  Algo satisfecho   9.316667
# 60          Medio   Muy seguro          Neutral   0.250000
# 183         Medio  Algo seguro  Algo satisfecho   2.772878
# 493         Medio   Muy seguro  Algo satisfecho   1.383333
# 582         Medio  Algo seguro  Algo satisfecho   5.583333
# 1309        Medio  Algo seguro  Algo satisfecho   1.583333
# 1563        Medio  Algo seguro          Neutral   1.583333
# 1932        Medio   Muy seguro  Algo satisfecho   1.750000
# 2047        Medio   Muy seguro          Neutral   1.583333
# 2381        Medio      Neutral          Neutral   1.000000

# %%
#contar renglones que tienen valores invalidos en limpieza
df[df_lim_r].count()
# Out:
# nrow             10
# id               10
# dia              10
# aerolinea        10
# destino          10
# region           10
# dest_size        10
# area_abordaje    10
# fecha_salida     10
# espera_min       10
# limpieza         10
# seguridad        10
# satisfaccion     10
# espera_hr        10
# dtype: int64

# %%
#contar renglones que tienen valores validos en limpieza
df[~df_lim_r].count()
# Out:
# nrow             2468
# id               2468
# dia              2468
# aerolinea        2468
# destino          2468
# region           2468
# dest_size        2468
# area_abordaje    2468
# fecha_salida     2468
# espera_min       2468
# limpieza         2468
# seguridad        2468
# satisfaccion     2468
# espera_hr        2468
# dtype: int64

# %%
#Reemplazar valores en una columna
df['limpieza'] = df['limpieza'].replace({'Inaceptable':"Sucio", 'Medio':'Promedio'})
set(df['limpieza']).difference(df_cat['limpieza'])
# Out:
# set()

# %%
#Validar columnas region, dest_size
print('Region', df['region'].unique())
print('Dest Size', df['dest_size'].unique())
# Out:
# Region ['Asia' 'Canada / Mexico' 'oeste de EE. UU.' 'East US' 'este de EE. UU.'
#  'Canadá / México' 'Oeste de EE. UU.' 'Medio Oeste de EE. UU.' 'EAST US'
#  'Medio Oriente' 'Este de EE. UU.' 'Europa' 'eur' 'Midwest US'
#  'Centroamérica / Sudamérica' 'Centro / Sudamérica' 'West US'
#  'ESTE de EE. UU.' 'Australia / Nueva Zelanda' 'Medio oeste de EE. UU.'
#  'oriente medio' 'ESTE DE EE. UU.' 'Medio oriente'
#  'Medio Oeste de los EE. UU.' 'Oriente Medio']
# Dest Size ['Hub' 'Small' '  Hub ' 'Medium' 'Grande' '   Small' 'grande' 'Large']

# %% [markdown]
# #Transformar datos

# %%
#Pasar a minusculas
df['region'] = df['region'].str.lower()
df
# Out:
#       nrow    id        dia      aerolinea            destino  \
# 0        0  1351     martes    UNITED INTL             KANSAI
# 1        1   373    viernes         ALASKA  SAN JOSE DEL CABO
# 2        2  2820     jueves          DELTA        LOS ÁNGELES
# 3        3  1157     martes       SUDOESTE        LOS ÁNGELES
# 4        4  2992  miércoles       AMERICAN              MIAMI
# ...    ...   ...        ...            ...                ...
# 2475  2804  1475     martes         ALASKA     NUEVA YORK-JFK
# 2476  2805  2222     jueves       SUDOESTE            PHOENIX
# 2477  2806  2684    viernes         UNITED            ORLANDO
# 2478  2807  2549     martes        JETBLUE         LONG BEACH
# 2479  2808  2162     sábado  ESTE DE CHINA            QINGDAO
#
#                 region dest_size area_abordaje fecha_salida  espera_min  \
# 0                 asia       Hub  Gates 91-102   2018-12-31       115.0
# 1      canada / mexico     Small   Gates 50-59   2018-12-31       135.0
# 2     oeste de ee. uu.      Hub    Gates 40-48   2018-12-31        70.0
# 3     oeste de ee. uu.      Hub    Gates 20-39   2018-12-31       190.0
# 4              east us       Hub   Gates 50-59   2018-12-31       559.0
# ...                ...       ...           ...          ...         ...
# 2475   este de ee. uu.       Hub   Gates 50-59   2018-12-31       280.0
# 2476  oeste de ee. uu.      Hub    Gates 20-39   2018-12-31       165.0
# 2477   este de ee. uu.       Hub   Gates 70-90   2018-12-31        92.0
# 2478  oeste de ee. uu.     Small    Gates 1-12   2018-12-31        95.0
# 2479              asia    grande    Gates 1-12   2018-12-31       220.0
#
#          limpieza    seguridad     satisfaccion  espera_hr
# 0          Limpio      Neutral   Muy satisfecho   1.916667
# 1          Limpio   Muy seguro   Muy satisfecho   2.250000
# 2        Promedio  Algo seguro          Neutral   1.166667
# 3          Limpio   Muy seguro  Algo satisfecho   3.166667
# 4           Sucio   Muy seguro  Algo satisfecho   9.316667
# ...           ...          ...              ...        ...
# 2475  Algo limpio      Neutral  Algo satisfecho   4.666667
# 2476       Limpio   Muy seguro   Muy satisfecho   2.750000
# 2477       Limpio   Muy seguro   Muy satisfecho   1.533333
# 2478       Limpio  Algo seguro   Muy satisfecho   1.583333
# 2479       Limpio   Muy seguro  Algo satisfecho   3.666667
#
# [2478 rows x 14 columns]

# %%
#Reemplazar valores
df['region'] = df['region'].replace({'eur':'europa'})
df['region']
# Out:
# 0                   asia
# 1        canada / mexico
# 2       oeste de ee. uu.
# 3       oeste de ee. uu.
# 4                east us
#               ...
# 2475     este de ee. uu.
# 2476    oeste de ee. uu.
# 2477     este de ee. uu.
# 2478    oeste de ee. uu.
# 2479                asia
# Name: region, Length: 2478, dtype: object

# %%
#Quitar espacios en blanco
df['dest_size'] = df['dest_size'].str.strip()
df['dest_size']
# Out:
# 0          Hub
# 1        Small
# 2          Hub
# 3          Hub
# 4          Hub
#          ...
# 2475       Hub
# 2476       Hub
# 2477       Hub
# 2478     Small
# 2479    grande
# Name: dest_size, Length: 2478, dtype: object

# %%
df['dest_size'] = df['dest_size'].str.replace('grande', 'Large', regex=True, flags=re.IGNORECASE)
df['dest_size']
# Out:
# 0         Hub
# 1       Small
# 2         Hub
# 3         Hub
# 4         Hub
#         ...
# 2475      Hub
# 2476      Hub
# 2477      Hub
# 2478    Small
# 2479    Large
# Name: dest_size, Length: 2478, dtype: object
